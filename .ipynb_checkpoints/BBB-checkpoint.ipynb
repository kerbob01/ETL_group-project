# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
import pandas as pd
import psycopg2

# %%
csv_file = "open-beer-database.csv"
ob_df = pd.read_csv(csv_file)
ob_df.head()
# Out:
#                     Name      id  brewery_id  cat_id  style_id  \
# 0           Scottish Ale  1495.0       347.0     1.0      15.0
# 1     Het Kapittel Pater  1509.0       301.0    -1.0      -1.0
# 2         Export Premium  1516.0       785.0    -1.0      -1.0
# 3    Bee Sting Honey Ale  1527.0       604.0     3.0      26.0
# 4  PranQster Belgian Ale  1540.0       919.0    -1.0      -1.0
#
#    Alcohol By Volume  International Bitterness Units  \
# 0                5.8                             0.0
# 1                0.0                             0.0
# 2                5.4                             0.0
# 3                5.9                             0.0
# 4                7.6                             0.0
#
#    Standard Reference Method  Universal Product Code filepath  ...  \
# 0                        0.0                     0.0      NaN  ...
# 1                        0.0                     0.0      NaN  ...
# 2                        0.0                     0.0      NaN  ...
# 3                        0.0                     0.0      NaN  ...
# 4                        0.0                     0.0      NaN  ...
#
#                     last_mod                    Style            Category  \
# 0  2010-07-23T01:30:00+05:30               Scotch Ale         British Ale
# 1  2010-07-23T01:30:00+05:30                      NaN                 NaN
# 2  2010-07-23T01:30:00+05:30                      NaN                 NaN
# 3  2010-07-23T01:30:00+05:30  American-Style Pale Ale  North American Ale
# 4  2010-07-23T01:30:00+05:30                      NaN                 NaN
#
#                         Brewer                Address        City  \
# 0              Carlyle Brewing  215 East State Street    Rockford
# 1          Brouwerij Van Eecke            Douvieweg 2       Watou
# 2        Licher Privatbrauerei  In den Hardtberggrten        Lich
# 3         Great Divide Brewing   2201 Arapahoe Street      Denver
# 4  North Coast Brewing Company  455 North Main Street  Fort Bragg
#
#              State        Country        Coordinates  \
# 0         Illinois  United States  42.2689, -89.0907
# 1  West-Vlaanderen        Belgium    50.8612, 2.6615
# 2           Hessen        Germany    50.5208, 8.8166
# 3         Colorado  United States  39.7539, -104.989
# 4       California  United States  39.4466, -123.806
#
#                                      Website
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                http://www.greatdivide.com/
# 4  http://www.northcoastbrewing.com/home.htm
#
# [5 rows x 22 columns]

# %%
# unique values with drop_duplicates
df = ob_df.drop_duplicates(subset=['Name', 'brewery_id', 'Style' ])

# %%
Beers_location_df = ob_df[['Name', 'Brewer', 'brewery_id', 'id','Address', 'City', 'State', 'Country']].copy()
Beers_location_df.head()
# Out:
#                     Name                       Brewer  brewery_id      id  \
# 0           Scottish Ale              Carlyle Brewing       347.0  1495.0
# 1     Het Kapittel Pater          Brouwerij Van Eecke       301.0  1509.0
# 2         Export Premium        Licher Privatbrauerei       785.0  1516.0
# 3    Bee Sting Honey Ale         Great Divide Brewing       604.0  1527.0
# 4  PranQster Belgian Ale  North Coast Brewing Company       919.0  1540.0
#
#                  Address        City            State        Country
# 0  215 East State Street    Rockford         Illinois  United States
# 1            Douvieweg 2       Watou  West-Vlaanderen        Belgium
# 2  In den Hardtberggrten        Lich           Hessen        Germany
# 3   2201 Arapahoe Street      Denver         Colorado  United States
# 4  455 North Main Street  Fort Bragg       California  United States

# %%
Beers_location_df.rename(columns={'Name':'name', 'Brewer':'brewery', 'Address':'address', 'City':'city', 'State':'state','Country':'country'}, inplace=True)
Beers_location_df.head()
# Out:
#                     name                      brewery  brewery_id      id  \
# 0           Scottish Ale              Carlyle Brewing       347.0  1495.0
# 1     Het Kapittel Pater          Brouwerij Van Eecke       301.0  1509.0
# 2         Export Premium        Licher Privatbrauerei       785.0  1516.0
# 3    Bee Sting Honey Ale         Great Divide Brewing       604.0  1527.0
# 4  PranQster Belgian Ale  North Coast Brewing Company       919.0  1540.0
#
#                  address        city            state        country
# 0  215 East State Street    Rockford         Illinois  United States
# 1            Douvieweg 2       Watou  West-Vlaanderen        Belgium
# 2  In den Hardtberggrten        Lich           Hessen        Germany
# 3   2201 Arapahoe Street      Denver         Colorado  United States
# 4  455 North Main Street  Fort Bragg       California  United States

# %%
engine_beer=create_engine(f'postgresql://postgres:postgres@localhost:5432/craft_beers')
# Base.metadata.create(engine_beer)
Base.metadata.create_all(engine_beer)

# %%
engine_beer.table_names()
# Out:
# ['Beers', 'Beers_location']

# %%
Beers_location_df.to_sql(name='Beers_location', con=engine_beer, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from "Beers_location"', con=engine_beer).head()
# Out:
#                     name                      brewery  brewery_id      id  \
# 0           Scottish Ale              Carlyle Brewing       347.0  1495.0
# 1     Het Kapittel Pater          Brouwerij Van Eecke       301.0  1509.0
# 2         Export Premium        Licher Privatbrauerei       785.0  1516.0
# 3    Bee Sting Honey Ale         Great Divide Brewing       604.0  1527.0
# 4  PranQster Belgian Ale  North Coast Brewing Company       919.0  1540.0
#
#                  address        city            state        country
# 0  215 East State Street    Rockford         Illinois  United States
# 1            Douvieweg 2       Watou  West-Vlaanderen        Belgium
# 2  In den Hardtberggrten        Lich           Hessen        Germany
# 3   2201 Arapahoe Street      Denver         Colorado  United States
# 4  455 North Main Street  Fort Bragg       California  United States
